# %%
# %cd /content/drive/MyDrive/a4/student
# Out:
# /content/drive/MyDrive/a4/student

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.insert(0, '/content/drive/MyDrive/python_packages')

# %%
# %run run.py train --train-src=./zh_en_data/train.zh --train-tgt=./zh_en_data/train.en --dev-src=./zh_en_data/dev.zh --dev-tgt=./zh_en_data/dev.en --vocab=vocab.json --cuda --lr=5e-4 --patience=1 --valid-niter=200 --batch-size=32 --dropout=.3
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cuda:0
# begin Maximum Likelihood training
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:309: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:1003.)
#   return F.conv1d(input, weight, bias, self.stride,
# epoch 1, iter 10, avg. loss 208.17, avg. ppl 2811.63 cum. examples 320, speed 2670.98 words/sec, time elapsed 3.14 sec
# epoch 1, iter 20, avg. loss 180.33, avg. ppl 1170.26 cum. examples 640, speed 5713.29 words/sec, time elapsed 4.57 sec
# epoch 1, iter 30, avg. loss 173.26, avg. ppl 866.62 cum. examples 960, speed 5676.73 words/sec, time elapsed 6.02 sec
# ...
