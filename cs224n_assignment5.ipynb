# %%
# %cd /content/drive/MyDrive/a5/student_2023
# Out:
# /content/drive/MyDrive/a5/student_2023

# %%
# %run ./src/run.py finetune vanilla wiki.txt --writing_params_path vanilla.model.params --finetune_corpus_path birth_places_train.tsv
# Out:
# data has 418351 characters, 256 unique.
# number of parameters: 3323392
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# epoch 1 iter 7: train loss 3.41325. lr 5.999844e-04: 100%|██████████| 8/8 [00:05<00:00,  1.56it/s]
# epoch 2 iter 7: train loss 2.67111. lr 5.999351e-04: 100%|██████████| 8/8 [00:02<00:00,  3.56it/s]
# epoch 3 iter 7: train loss 2.35626. lr 5.998520e-04: 100%|██████████| 8/8 [00:02<00:00,  3.30it/s]
# epoch 4 iter 7: train loss 2.17262. lr 5.997351e-04: 100%|██████████| 8/8 [00:02<00:00,  3.34it/s]
# ...

# %%
# %run ./src/run.py evaluate vanilla wiki.txt --reading_params_path vanilla.model.params --eval_corpus_path birth_dev.tsv --outputs_path vanilla.nopretrain.dev.predictions
# Out:
# data has 418351 characters, 256 unique.
# number of parameters: 3323392
# 500it [01:08,  7.32it/s]
# Correct: 11.0 out of 500.0: 2.1999999999999997%

# %%
# %run ./src/run.py evaluate vanilla wiki.txt --reading_params_path vanilla.model.params --eval_corpus_path birth_test_inputs.tsv --outputs_path vanilla.nopretrain.test.predictions
# Out:
# data has 418351 characters, 256 unique.
# number of parameters: 3323392
# 437it [01:00,  7.22it/s]
# No gold birth places provided; returning (0,0)
# Predictions written to vanilla.nopretrain.test.predictions; no targets provided

# %%
# %run ./src/run.py pretrain vanilla wiki.txt --writing_params_path vanilla.pretrain.params
# Out:
# data has 418351 characters, 256 unique.
# number of parameters: 3323392
# epoch 1 iter 22: train loss 3.47168. lr 5.999655e-03: 100%|██████████| 23/23 [00:03<00:00,  6.28it/s]
# epoch 2 iter 22: train loss 3.22952. lr 5.998582e-03: 100%|██████████| 23/23 [00:03<00:00,  6.38it/s]
# epoch 3 iter 22: train loss 3.02839. lr 5.996780e-03: 100%|██████████| 23/23 [00:03<00:00,  6.32it/s]
# epoch 4 iter 22: train loss 2.92062. lr 5.994250e-03: 100%|██████████| 23/23 [00:03<00:00,  6.20it/s]
# epoch 5 iter 22: train loss 2.82895. lr 5.990993e-03: 100%|██████████| 23/23 [00:03<00:00,  6.40it/s]
# epoch 6 iter 22: train loss 2.80025. lr 5.987009e-03: 100%|██████████| 23/23 [00:03<00:00,  6.37it/s]
# epoch 7 iter 22: train loss 2.78194. lr 5.982299e-03: 100%|██████████| 23/23 [00:03<00:00,  6.26it/s]
# epoch 8 iter 22: train loss 2.75855. lr 5.976865e-03: 100%|██████████| 23/23 [00:03<00:00,  6.23it/s]
# ...

# %%
# %run ./src/run.py finetune vanilla wiki.txt --reading_params_path vanilla.pretrain.params --writing_params_path vanilla.finetune.params --finetune_corpus_path birth_places_train.tsv
# Out:
# data has 418351 characters, 256 unique.
# number of parameters: 3323392
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# epoch 1 iter 7: train loss 0.72254. lr 5.999844e-04: 100%|██████████| 8/8 [00:02<00:00,  3.12it/s]
# epoch 2 iter 7: train loss 0.58925. lr 5.999351e-04: 100%|██████████| 8/8 [00:02<00:00,  3.13it/s]
# epoch 3 iter 7: train loss 0.48157. lr 5.998520e-04: 100%|██████████| 8/8 [00:02<00:00,  3.18it/s]
# epoch 4 iter 7: train loss 0.40098. lr 5.997351e-04: 100%|██████████| 8/8 [00:02<00:00,  3.02it/s]
# ...

# %%
# %run ./src/run.py evaluate vanilla wiki.txt --reading_params_path vanilla.finetune.params --eval_corpus_path birth_dev.tsv --outputs_path vanilla.pretrain.dev.predictions
# Out:
# data has 418351 characters, 256 unique.
# number of parameters: 3323392
# 500it [01:06,  7.51it/s]
# Correct: 120.0 out of 500.0: 24.0%

# %%
# %run ./src/run.py evaluate vanilla wiki.txt --reading_params_path vanilla.finetune.params --eval_corpus_path birth_test_inputs.tsv --outputs_path vanilla.pretrain.test.predictions
# Out:
# data has 418351 characters, 256 unique.
# number of parameters: 3323392
# 408it [01:00,  5.51it/s]

# %%
# %run ./src/run.py pretrain perceiver wiki.txt --bottleneck_dim 64 --pretrain_lr 6e-3 --writing_params_path perceiver.pretrain.params
# Out:
# data has 418351 characters, 256 unique.
# number of parameters: 3339776
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# epoch 1 iter 22: train loss 3.44615. lr 5.999655e-03: 100%|██████████| 23/23 [00:05<00:00,  3.89it/s]
# epoch 2 iter 22: train loss 3.44115. lr 5.998582e-03: 100%|██████████| 23/23 [00:02<00:00, 10.48it/s]
# epoch 3 iter 22: train loss 3.40589. lr 5.996780e-03: 100%|██████████| 23/23 [00:02<00:00, 10.77it/s]
# epoch 4 iter 22: train loss 3.43257. lr 5.994250e-03: 100%|██████████| 23/23 [00:02<00:00, 10.83it/s]
# ...

# %%
# %run ./src/run.py finetune perceiver wiki.txt --bottleneck_dim 64 --reading_params_path perceiver.pretrain.params --writing_params_path perceiver.finetune.params --finetune_corpus_path birth_places_train.tsv
# Out:
# data has 418351 characters, 256 unique.
# number of parameters: 3339776
# epoch 1 iter 7: train loss 0.96201. lr 5.999844e-04: 100%|██████████| 8/8 [00:01<00:00,  4.93it/s]
# epoch 2 iter 7: train loss 0.82865. lr 5.999351e-04: 100%|██████████| 8/8 [00:01<00:00,  5.34it/s]
# epoch 3 iter 7: train loss 0.76940. lr 5.998520e-04: 100%|██████████| 8/8 [00:01<00:00,  5.06it/s]
# epoch 4 iter 7: train loss 0.71083. lr 5.997351e-04: 100%|██████████| 8/8 [00:01<00:00,  5.23it/s]
# epoch 5 iter 7: train loss 0.66794. lr 5.995844e-04: 100%|██████████| 8/8 [00:01<00:00,  5.14it/s]
# epoch 6 iter 7: train loss 0.64461. lr 5.993999e-04: 100%|██████████| 8/8 [00:01<00:00,  4.93it/s]
# epoch 7 iter 7: train loss 0.60400. lr 5.991818e-04: 100%|██████████| 8/8 [00:01<00:00,  4.74it/s]
# epoch 8 iter 7: train loss 0.56903. lr 5.989299e-04: 100%|██████████| 8/8 [00:01<00:00,  5.00it/s]
# epoch 9 iter 7: train loss 0.53950. lr 5.986444e-04: 100%|██████████| 8/8 [00:01<00:00,  5.06it/s]
# ...

# %%
# %run ./src/run.py evaluate perceiver wiki.txt --bottleneck_dim 64 --reading_params_path perceiver.finetune.params --eval_corpus_path birth_dev.tsv --outputs_path perceiver.pretrain.dev.predictions
# Out:
# data has 418351 characters, 256 unique.
# number of parameters: 3339776
# 500it [00:59,  8.34it/s]
# Correct: 30.0 out of 500.0: 6.0%

# %%
# %run ./src/run.py evaluate perceiver wiki.txt --bottleneck_dim 64 --reading_params_path perceiver.finetune.params --eval_corpus_path  birth_test_inputs.tsv --outputs_path perceiver.pretrain.test.predictions
# Out:
# data has 418351 characters, 256 unique.
# number of parameters: 3339776
# 437it [00:54,  8.07it/s]
# No gold birth places provided; returning (0,0)
# Predictions written to perceiver.pretrain.test.predictions; no targets provided
